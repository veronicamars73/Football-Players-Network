# %% [markdown]
# # Player Data Analysis from Transfermarkt
# This notebook constructs a graph of players and their most played teammates using data from Transfermarkt.
# The aim is to analyze relationships between players using graph analysis techniques, uncovering key insights such as:

# %% [markdown]
# ## 1. Importing Necessary Libraries and Setting Constants
#
# In this section, we import the libraries required for:
# - **Data manipulation** (`pandas`)
# - **Graph construction and analysis** (`networkx`)
# - **Interactive visualization** (`plotly`)
# - **Web scraping** (`selenium` and `BeautifulSoup`)
# - **Utility Libraries** (`time` and `re`)
#
# Moreover, the Constants, concern the amount of data that will be gathered during the scrapping process.
# - **NUM_PLAYERS**: represents the amount of players from the top most valuable players in the world will be considered
# - **NUM_TEAMMATES**: the number of teammates wich will be accessed for each player.

# %%
# 1. Data Manipulation
import pandas as pd  # For handling and analyzing structured data

# 2. Graph Construction
import networkx as nx  # For creating and analyzing network graphs

# 3. Data Visualization
import plotly.graph_objs as go  # For interactive graph visualization

# 4. Web Scraping
from selenium import webdriver  # Automates browser interaction
from selenium.webdriver.chrome.service import Service  # For managing the Chrome service
from bs4 import BeautifulSoup  # For parsing HTML data

# 5. Utility Libraries
import time  # For adding delays in scraping
import re  # For regular expressions, used to clean and extract data

# %%
NUM_PLAYERS = 75
NUM_TEAMMATES = 5

# %% [markdown]
# ## 2. Setting Up WebDriver Service
#
# In this section, we set up the Chrome WebDriver using Selenium. This allows us to interact with web pages for scraping data from Transfermarkt.
# Steps:
# 1. **Configure Chrome Options**: Set any preferences such as headless mode if needed.
# 2. **Specify the WebDriver Path**: Provide the path to the Chrome WebDriver executable.
# 3. **Initialize the WebDriver**: Launch Chrome with the configured options.

# %%
# 2. Setting up the WebDriver

# Configuring Chrome options (e.g., headless mode can be set here if needed)
chrome_options = webdriver.chrome.options.Options()

# Path to the Chrome WebDriver executable
chrome_driver = "C:\\Users\\Lisandra\\Documents\\webdriver\\chromedriver-win64\\chromedriver.exe"

# Initializing the WebDriver service with the executable path
service_to_pass = Service(executable_path=chrome_driver)

# Launching the WebDriver with the service and options
wd = webdriver.Chrome(service=service_to_pass, options=chrome_options)

# %% [markdown]
# ## 3. Defining Functions Used in the Notebook
#
# This section defines utility functions that are used to scrape player data and process the information. These functions are modular, making it easier to manage different components of the scraping and analysis workflow.
#
# ### Function: `scrape_page()`
# - **Purpose**: Extract player information (name and player profile link) from a page containing a list of the most valuable players.
# - **Args**:
#   - `html` (str): The raw HTML source of the web page to be scraped.
# - **Returns**:
#   - None (Modifies the global `players_data` list by appending player details).
#
# ### Function: `scrape_teammates()`
# - **Purpose**: Extract information about a player's most frequently played teammates, including their names and profile links, from a web page.
# - **Args**:
#   - `html` (str): The HTML source of the web page that contains teammate information.
# - **Returns**:
#   - `teamates_vet` (DataFrame): A pandas DataFrame containing the extracted teammate names and links.
#
# ### Function: `change_page()`
# - **Purpose**: Extract the URL for the next page in a paginated list of players or teammates.
# - **Args**:
#   - `html` (str): The HTML source of the current page.
# - **Returns**:
#   - `link` (str): The URL of the next page to be scraped.
#
# ### Function: `name_to_url()`
# - **Purpose**: Converts a player's name into a formatted URL that can be used to access their profile on Transfermarkt.
# - **Args**:
#   - `player_name` (str): The name of the player to be converted into a URL.
# - **Returns**:
#   - `url` (str): The formatted Transfermarkt URL for the player's profile.
#
# ### Function: `extract_player_name()`
# - **Purpose**: Extracts a player's name from a Transfermarkt profile URL and converts it into a readable format.
# - **Args**:
#   - `url` (str): The URL from which the player's name will be extracted.
# - **Returns**:
#   - `player_name` (str): The formatted player name, with hyphens replaced by spaces and proper capitalization.
#   - If no match is found, the original URL is returned.
#
# ### Function: `teamates_page()`
# - **Purpose**: Modifies a player's profile URL to navigate to the page listing the player's most frequently played teammates.
# - **Args**:
#   - `df_row` (Series): A row from the DataFrame that contains player data, including their profile URL.
# - **Returns**:
#   - `url` (str): The modified URL pointing to the player's teammates page.
#
# ### Function: `check_players_in_graph()`
# - **Purpose**: Checks if two players are present as nodes in the graph.
# - **Args**:
#   - `graph` (NetworkX Graph): The graph where player nodes are stored.
#   - `player1` (str): The name of the first player to check.
#   - `player2` (str): The name of the second player to check.
# - **Returns**:
#   - `result` (bool): `True` if both players are found in the graph, otherwise `False`.
# - **Additional Behavior**:
#   - If only one player is found, a message is printed indicating which player is missing.
#   - If neither player is found, a message is printed indicating that both are missing.
#
# ### Function: `add_to_graph()`
# - **Purpose**: Adds a player and their teammates to a NetworkX graph (`G`), creating nodes for each player and adding edges to represent their connections.
# - **Args**:
#   - `player` (dict): A dictionary containing information about the player to be added as a node.
#   - `teammates` (DataFrame): A DataFrame containing teammate data to be added as nodes and connected to the player.
# - **Returns**:
#   - None (modifies the global graph `G` in place).
# - **Behavior**:
#   - Adds a node for the player if it doesn’t already exist.
#   - Adds nodes for each teammate.
#   - Adds an edge between the player and each teammate, ensuring no duplicate edges.

# %%
# 3.1 Scrape Player Information from a Web Page

def scrape_page(html):
    """
    Extracts player information from a web page of the most valuable players. 
    The information of each player is added to the players_data list.

    Args:
        html (str): The page source that will be scraped.

    Returns:
        None: Appends player information to the global players_data list.
    """
    soup = BeautifulSoup(html, 'html.parser')
    
    # Find all player rows in the table (rows with 'odd' and 'even' class)
    player_rows = soup.find_all('tr', class_=['odd', 'even'])
    
    # Extract player information from each row
    for player in player_rows:
        name = player.find_all('td')[1].find('img').get('alt')  # Player's name
        player_link = 'https://www.transfermarkt.com' + player.find('td', class_='hauptlink').find('a')['href']  # Player page link
        
        # Add player data to the global list (uncomment if needed: rank, age, club, market value)
        players_data.append({
            'Name': name,
            'Player Page': player_link,
        })

# %%
# 3.2 Scrape Teammate Information from a Player's Page

def scrape_teammates(html):
    """
    Extracts players information from a web page of a player's most played teammates. 
    The information of each player is added to the players_data list.

    Args:
        html (str): The page source that will be scraped.

    Returns:
        teamates_vet (DataFrame): A DataFrame of all the teammates on the page.
    """
    soup = BeautifulSoup(html, 'html.parser')
    
    # Find the table containing teammate data
    teammate_table = soup.find('table', {'class': 'items'})
    teamates_vet = []  # List to store teammate data
    count_runs = 0  # Counter to handle iterations over the rows

    for tm in teammate_table.find_all('tr')[1:]:  # Skip the header row
        if count_runs % 3 == 0:  # Process every third row
            try:
                # Extract teammate name and profile link
                teammate_name = tm.find('img').get('alt')
                player_link = 'https://www.transfermarkt.com' + tm.find('td', class_='hauptlink').find('a')['href']
                
                # Add teammate data to global players_data and local teamates_vet
                players_data.append({
                    'Name': teammate_name,
                    'Player Page': player_link,
                })
                teamates_vet.append({
                    'Name': teammate_name,
                    'Player Page': player_link,
                })
            except:
                # Handle any errors in data extraction gracefully
                print("There was a problem gathering data from the row below")
                print(tm)
        
        count_runs += 1  # Increment the counter

    # Return the collected teammate data as a DataFrame
    return pd.DataFrame(teamates_vet)

# %%
# 3.3 Extract the Link to the Next Page in Pagination

def change_page(html):
    """
    Extracts the URL of the next page from a paginated web page.

    Args:
        html (str): The HTML source of the current page.

    Returns:
        link (str): The URL of the next page to be scraped.
    """
    soup = BeautifulSoup(html, 'html.parser')

    # Find the 'Next Page' button and extract the link
    next_button = soup.find('li', class_='tm-pagination__list-item tm-pagination__list-item--icon-next-page')
    link = 'https://www.transfermarkt.com' + next_button.find('a')['href']
    
    return link

# %%
# 3.4 Convert a Player's Name into a Transfermarkt Profile URL

def name_to_url(player_name):
    """
    Converts a player's name into a URL for their Transfermarkt profile.
    
    Args:
        player_name (str): The name of the player to be converted into a URL.

    Returns:
        url (str): The formatted Transfermarkt URL for the player's profile.
    """
    # Convert the name to lowercase and replace spaces with hyphens
    formatted_name = player_name.lower().replace(" ", "-")
    
    # Construct the URL
    url = f"https://www.transfermarkt.com/{formatted_name}/profil/spieler/"
    
    return url

# %%
# 3.5 Extract Player Name from a Transfermarkt Profile URL

def extract_player_name(url):
    """
    Extracts the player's name from a Transfermarkt profile URL and formats it.
    
    Args:
        url (str): The URL from which the player's name will be extracted.

    Returns:
        player_name (str): The player's name with hyphens replaced by spaces and proper capitalization.
        If no match is found, the original URL is returned.
    """
    # Use regex to find the player name part of the URL
    match = re.search(r'transfermarkt\.com/([^/]+)/', url)
    
    if match:
        # Extract the name and replace hyphens with spaces
        player_name = match.group(1).replace("-", " ")
        
        # Capitalize the first letter of each word (e.g., 'john-doe' becomes 'John Doe')
        player_name = player_name.title()
        return player_name
    
    # Return the original URL if no match is found
    return url

# %%
# 3.6 Convert Player Profile URL to Teammates Page URL

def teamates_page(df_row):
    """
    Modifies a player's profile URL to navigate to the page listing their most frequently played teammates.

    Args:
        df_row (Series): A row from the DataFrame containing the player's profile URL.

    Returns:
        url (str): The modified URL pointing to the player's teammates page.
    """
    # Replace "profil" with "gemeinsameSpiele" in the player's profile URL to get the teammates page URL
    return df_row['Player Page'].replace("profil", "gemeinsameSpiele")

# %%
# 3.7 Check if Two Players Exist in the Graph

def check_players_in_graph(graph, player1, player2):
    """
    Checks if two players (player1 and player2) are present as nodes in the graph.

    Args:
        graph (NetworkX Graph): The graph where player nodes are stored.
        player1 (str): The name of the first player to check.
        player2 (str): The name of the second player to check.

    Returns:
        bool: True if both players are found in the graph, otherwise False.
        
    Additional Behavior:
        - Prints a message if only one player is found or if both are missing.
    """
    # Check if player1 and player2 URLs are present as nodes in the graph
    player1_exists = any(name_to_url(player1) in node for node in graph.nodes)
    player2_exists = any(name_to_url(player2) in node for node in graph.nodes)
    
    # Return the result and print relevant messages
    if player1_exists and player2_exists:
        return True
    elif player1_exists:
        print(f"Player '{player1}' exists, but player '{player2}' does not exist in the graph.")
        return False
    elif player2_exists:
        print(f"Player '{player2}' exists, but player '{player1}' does not exist in the graph.")
        return False
    print(f"Neither player '{player1}' nor player '{player2}' exists in the graph.")
    return False

# %%
# 3.8 Add a Player and Their Teammates to the Graph

def add_to_graph(player, teammates):
    """
    Adds a player and their teammates to a NetworkX graph (G), creating nodes and edges.

    Args:
        player (dict): A dictionary containing player data to be added as a node.
        teammates (DataFrame): A DataFrame containing teammate data to be added as nodes and connected to the player.

    Returns:
        None: Modifies the global graph G in place.
    """
    # Add the player as a node if not already in the graph
    if player['Player Page'] not in G:
        G.add_node(player['Player Page'], data=player)

    # Iterate through the teammates DataFrame
    for index, row in teammates.iterrows():
        # Add the teammate as a node if not already in the graph
        if row['Player Page'] not in G:
            G.add_node(row['Player Page'], data=row)
        
        # Add an edge between the player and teammate if no existing edge is found
        if not G.has_edge(player['Player Page'], row['Player Page']) and not G.has_edge(row['Player Page'], player['Player Page']):
            G.add_edge(player['Player Page'], row['Player Page'])

# %% [markdown]
# ## 4. Accessing and Scraping the Most Valuable Players Webpage
# This section collects data from the Transfermarkt webpage, which lists the most valuable players. The data includes player names and profile URLs. We use a loop to paginate through the pages and gather information on 250 players or stop if no more players are available.
# Futhermore, a treatment is applied to add a column corresponding to the teammates page for each player.

# %%
# Define the URL for the most valuable players on Transfermarkt
url = 'https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?land_id=0&ausrichtung=alle&spielerposition_id=alle&altersklasse=alle&jahrgang=0&kontinent_id=0&plus=1'
# Open the webpage using the Selenium webdriver
wd.get(url)

# %%
# Initialize an empty list to store player data
players_data = []
# Pagination: Continue scraping until you gather 250 players or run out of pages
players_count = 0

while players_count < NUM_PLAYERS:
    time.sleep(2)  # Wait for the page to fully load
    
    # Scrape data from the current page
    try:
        scrape_page(wd.page_source)  # Scrape player data from the current page
        players_count = len(players_data)  # Update the player count
        
        # Move to the next page using the 'change_page' function
        url = change_page(wd.page_source)
        wd.get(url)
    except:
        print('There was a problem accessing the data or no more players were found')
        break

# %%
# Convert the players data list into a DataFrame for future analysis
df_players = pd.DataFrame.from_dict(players_data[:NUM_PLAYERS])
df_players
# Out:
#                Name                                        Player Page
# 0   Jude Bellingham  https://www.transfermarkt.com/jude-bellingham/...
# 1    Erling Haaland  https://www.transfermarkt.com/erling-haaland/p...
# 2   Vinicius Junior  https://www.transfermarkt.com/vinicius-junior/...
# 3     Kylian Mbappé  https://www.transfermarkt.com/kylian-mbappe/pr...
# 4        Phil Foden  https://www.transfermarkt.com/phil-foden/profi...
# ..              ...                                                ...
# 70        Dani Olmo  https://www.transfermarkt.com/dani-olmo/profil...
# 71  Ousmane Dembélé  https://www.transfermarkt.com/ousmane-dembele/...
# 72  Marcus Rashford  https://www.transfermarkt.com/marcus-rashford/...
# 73    Jack Grealish  https://www.transfermarkt.com/jack-grealish/pr...
# 74    Kobbie Mainoo  https://www.transfermarkt.com/kobbie-mainoo/pr...
#
# [75 rows x 2 columns]

# %%
# Add a new column to the DataFrame with URLs to each player's teammates page
df_players['Teammates Page'] = df_players.apply(teamates_page, axis=1)

# %% [markdown]
# ## 5. Accessing Teammate Data and Building a Graph
# In this section, we access each player's "Teammates Page" to scrape data on their most frequently played teammates. For each player, we scrape up to 25 teammates and build a graph where players and their teammates are represented as nodes, and their relationships are edges. The graph helps us analyze the relationships between players based on their shared game time.
#
# We use pagination to ensure we gather enough teammates and then add both players and teammates to the graph.

# %%
# Initialize an empty graph to store players and their relationships
G = nx.Graph()

# Iterate through each player in the DataFrame
for index, row in df_players.iterrows():
    url = row['Teammates Page']
    wd.get(url)  # Open the player's teammates page
    row = row.drop(labels='Teammates Page')  # Drop the teammates page URL from the current row for cleaner data
    
    # Initialize variables to store teammate data
    teammate_count = 0
    teammates = pd.DataFrame(columns=['Name', 'Player Page'])  # Empty DataFrame to store teammates
    
    # Loop to gather up to 25 teammates from each player's page
    while teammate_count < NUM_TEAMMATES:
        # Scrape teammate data from the current page
        page_teammates = scrape_teammates(wd.page_source)
        
        # Concatenate the current page's teammates to the overall list
        teammates = pd.concat([teammates, page_teammates[:NUM_TEAMMATES]])
        teammate_count = len(teammates)
        
        # Try to navigate to the next page of teammates
        try:
            url = change_page(wd.page_source)
            wd.get(url)
        except:
            print('There was a problem accessing the data or no more players were found')
            break
    
    # Print the scraped teammates and player data for debugging
    print(teammates)
    print(row)
    
    # Add the player and their teammates to the graph
    add_to_graph(row, teammates)
# Out:
#                 Name                                        Player Page
# 0       Mats Hummels  https://www.transfermarkt.com/mats-hummels/pro...
# 1         Marco Reus  https://www.transfermarkt.com/marco-reus/profi...
# 2      Julian Brandt  https://www.transfermarkt.com/julian-brandt/pr...
# 3  Raphaël Guerreiro  https://www.transfermarkt.com/raphael-guerreir...
# 4           Emre Can  https://www.transfermarkt.com/emre-can/profil/...
# Name                                             Jude Bellingham
# Player Page    https://www.transfermarkt.com/jude-bellingham/...
# Name: 0, dtype: object
#              Name                                        Player Page
# 0   Manuel Akanji  https://www.transfermarkt.com/manuel-akanji/pr...
# 1           Rodri  https://www.transfermarkt.com/rodri/profil/spi...
# 2  Bernardo Silva  https://www.transfermarkt.com/bernardo-silva/p...
# 3         Ederson  https://www.transfermarkt.com/ederson/profil/s...
# 4      Phil Foden  https://www.transfermarkt.com/phil-foden/profi...
# Name                                              Erling Haaland
# Player Page    https://www.transfermarkt.com/erling-haaland/p...
# Name: 1, dtype: object
#                 Name                                        Player Page
# 0        Luka Modric  https://www.transfermarkt.com/luka-modric/prof...
# 1  Federico Valverde  https://www.transfermarkt.com/federico-valverd...
# 2         Toni Kroos  https://www.transfermarkt.com/toni-kroos/profi...
# 3   Thibaut Courtois  https://www.transfermarkt.com/thibaut-courtois...
# 4      Karim Benzema  https://www.transfermarkt.com/karim-benzema/pr...
# Name                                             Vinicius Junior
# Player Page    https://www.transfermarkt.com/vinicius-junior/...
# Name: 2, dtype: object
#                Name                                        Player Page
# 0        Marquinhos  https://www.transfermarkt.com/marquinhos/profi...
# 1  Presnel Kimpembe  https://www.transfermarkt.com/presnel-kimpembe...
# 2    Marco Verratti  https://www.transfermarkt.com/marco-verratti/p...
# 3    Ángel Di María  https://www.transfermarkt.com/angel-di-maria/p...
# 4            Neymar  https://www.transfermarkt.com/neymar/profil/sp...
# Name                                               Kylian Mbappé
# Player Page    https://www.transfermarkt.com/kylian-mbappe/pr...
# Name: 3, dtype: object
#              Name                                        Player Page
# 0     Kyle Walker  https://www.transfermarkt.com/kyle-walker/prof...
# 1         Ederson  https://www.transfermarkt.com/ederson/profil/s...
# 2  Bernardo Silva  https://www.transfermarkt.com/bernardo-silva/p...
# 3           Rodri  https://www.transfermarkt.com/rodri/profil/spi...
# 4     John Stones  https://www.transfermarkt.com/john-stones/prof...
# Name                                                  Phil Foden
# Player Page    https://www.transfermarkt.com/phil-foden/profi...
# Name: 4, dtype: object
#                  Name                                        Player Page
# 0   Gabriel Magalhães  https://www.transfermarkt.com/gabriel-magalhae...
# 1  Gabriel Martinelli  https://www.transfermarkt.com/gabriel-martinel...
# 2     Martin Ødegaard  https://www.transfermarkt.com/martin-odegaard/...
# 3        Granit Xhaka  https://www.transfermarkt.com/granit-xhaka/pro...
# 4       Eddie Nketiah  https://www.transfermarkt.com/eddie-nketiah/pr...
# Name                                                 Bukayo Saka
# Player Page    https://www.transfermarkt.com/bukayo-saka/prof...
# Name: 5, dtype: object
#                Name                                        Player Page
# 0      Jonathan Tah  https://www.transfermarkt.com/jonathan-tah/pro...
# 1    Lukas Hradecky  https://www.transfermarkt.com/lukas-hradecky/p...
# 2    Edmond Tapsoba  https://www.transfermarkt.com/edmond-tapsoba/p...
# 3  Jeremie Frimpong  https://www.transfermarkt.com/jeremie-frimpong...
# 4      Moussa Diaby  https://www.transfermarkt.com/moussa-diaby/pro...
# Name                                               Florian Wirtz
# Player Page    https://www.transfermarkt.com/florian-wirtz/pr...
# Name: 6, dtype: object
#               Name                                        Player Page
# 0   Joshua Kimmich  https://www.transfermarkt.com/joshua-kimmich/p...
# 1       Leroy Sané  https://www.transfermarkt.com/leroy-sane/profi...
# 2     Manuel Neuer  https://www.transfermarkt.com/manuel-neuer/pro...
# 3    Thomas Müller  https://www.transfermarkt.com/thomas-muller/pr...
# 4  Alphonso Davies  https://www.transfermarkt.com/alphonso-davies/...
# Name                                               Jamal Musiala
# Player Page    https://www.transfermarkt.com/jamal-musiala/pr...
# Name: 7, dtype: object
#               Name                                        Player Page
# 0   Bernardo Silva  https://www.transfermarkt.com/bernardo-silva/p...
# 1          Ederson  https://www.transfermarkt.com/ederson/profil/s...
# 2       Phil Foden  https://www.transfermarkt.com/phil-foden/profi...
# 3  Kevin De Bruyne  https://www.transfermarkt.com/kevin-de-bruyne/...
# 4      Kyle Walker  https://www.transfermarkt.com/kyle-walker/prof...
# Name                                                       Rodri
# Player Page    https://www.transfermarkt.com/rodri/profil/spi...
# Name: 8, dtype: object
#                  Name                                        Player Page
# 0        Jules Koundé  https://www.transfermarkt.com/jules-kounde/pro...
# 1  Robert Lewandowski  https://www.transfermarkt.com/robert-lewandows...
# 2         Pau Cubarsí  https://www.transfermarkt.com/pau-cubarsi/prof...
# 3      İlkay Gündoğan  https://www.transfermarkt.com/ilkay-gundogan/p...
# 4               Pedri  https://www.transfermarkt.com/pedri/profil/spi...
# Name                                                Lamine Yamal
# Player Page    https://www.transfermarkt.com/lamine-yamal/pro...
# Name: 9, dtype: object
#                Name                                        Player Page
# 0   Vinicius Junior  https://www.transfermarkt.com/vinicius-junior/...
# 1        Toni Kroos  https://www.transfermarkt.com/toni-kroos/profi...
# 2           Rodrygo  https://www.transfermarkt.com/rodrygo/profil/s...
# 3       Luka Modric  https://www.transfermarkt.com/luka-modric/prof...
# 4  Thibaut Courtois  https://www.transfermarkt.com/thibaut-courtois...
# Name                                           Federico Valverde
# Player Page    https://www.transfermarkt.com/federico-valverd...
# Name: 10, dtype: object
#                Name                                        Player Page
# 0   Aaron Cresswell  https://www.transfermarkt.com/aaron-cresswell/...
# 1   Michail Antonio  https://www.transfermarkt.com/michail-antonio/...
# 2  Lukasz Fabianski  https://www.transfermarkt.com/lukasz-fabianski...
# 3     Pablo Fornals  https://www.transfermarkt.com/pablo-fornals/pr...
# 4    Angelo Ogbonna  https://www.transfermarkt.com/angelo-ogbonna/p...
# Name                                                 Declan Rice
# Player Page    https://www.transfermarkt.com/declan-rice/prof...
# Name: 11, dtype: object
#                 Name                                        Player Page
# 0  Federico Valverde  https://www.transfermarkt.com/federico-valverd...
# 1        Luka Modric  https://www.transfermarkt.com/luka-modric/prof...
# 2         Toni Kroos  https://www.transfermarkt.com/toni-kroos/profi...
# 3    Vinicius Junior  https://www.transfermarkt.com/vinicius-junior/...
# 4   Thibaut Courtois  https://www.transfermarkt.com/thibaut-courtois...
# Name                                                     Rodrygo
# Player Page    https://www.transfermarkt.com/rodrygo/profil/s...
# Name: 12, dtype: object
#                  Name                                        Player Page
# 0      Nicolò Barella  https://www.transfermarkt.com/nicolo-barella/p...
# 1      Stefan de Vrij  https://www.transfermarkt.com/stefan-de-vrij/p...
# 2    Marcelo Brozovic  https://www.transfermarkt.com/marcelo-brozovic...
# 3    Samir Handanovič  https://www.transfermarkt.com/samir-handanovic...
# 4  Alessandro Bastoni  https://www.transfermarkt.com/alessandro-basto...
# Name                                            Lautaro Martínez
# Player Page    https://www.transfermarkt.com/lautaro-martinez...
# Name: 13, dtype: object
#                  Name                                        Player Page
# 0   Gabriel Magalhães  https://www.transfermarkt.com/gabriel-magalhae...
# 1         Bukayo Saka  https://www.transfermarkt.com/bukayo-saka/prof...
# 2           Ben White  https://www.transfermarkt.com/ben-white/profil...
# 3  Gabriel Martinelli  https://www.transfermarkt.com/gabriel-martinel...
# 4       Thomas Partey  https://www.transfermarkt.com/thomas-partey/pr...
# Name                                             Martin Ødegaard
# Player Page    https://www.transfermarkt.com/martin-odegaard/...
# Name: 14, dtype: object
#                 Name                                        Player Page
# 0    Vinicius Junior  https://www.transfermarkt.com/vinicius-junior/...
# 1  Federico Valverde  https://www.transfermarkt.com/federico-valverd...
# 2            Rodrygo  https://www.transfermarkt.com/rodrygo/profil/s...
# 3    Nacho Fernández  https://www.transfermarkt.com/nacho-fernandez/...
# 4    Daniel Carvajal  https://www.transfermarkt.com/daniel-carvajal/...
# Name                                           Eduardo Camavinga
# Player Page    https://www.transfermarkt.com/eduardo-camaving...
# Name: 15, dtype: object
#                 Name                                        Player Page
# 0  Wissam Ben Yedder  https://www.transfermarkt.com/wissam-ben-yedde...
# 1    Youssouf Fofana  https://www.transfermarkt.com/youssouf-fofana/...
# 2      Kevin Volland  https://www.transfermarkt.com/kevin-volland/pr...
# 3  Eduardo Camavinga  https://www.transfermarkt.com/eduardo-camaving...
# 4            Rodrygo  https://www.transfermarkt.com/rodrygo/profil/s...
# Name                                         Aurélien Tchouaméni
# Player Page    https://www.transfermarkt.com/aurelien-tchouam...
# Name: 16, dtype: object
#                   Name                                        Player Page
# 0  Giovanni Di Lorenzo  https://www.transfermarkt.com/giovanni-di-lore...
# 1      Piotr Zieliński  https://www.transfermarkt.com/piotr-zielinski/...
# 2      Matteo Politano  https://www.transfermarkt.com/matteo-politano/...
# 3    Stanislav Lobotka  https://www.transfermarkt.com/stanislav-lobotk...
# 4          Eljif Elmas  https://www.transfermarkt.com/eljif-elmas/prof...
# Name                                              Victor Osimhen
# Player Page    https://www.transfermarkt.com/victor-osimhen/p...
# Name: 17, dtype: object
#                 Name                                        Player Page
# 0          Eric Dier  https://www.transfermarkt.com/eric-dier/profil...
# 1        Hugo Lloris  https://www.transfermarkt.com/hugo-lloris/prof...
# 2      Heung-min Son  https://www.transfermarkt.com/heung-min-son/pr...
# 3         Ben Davies  https://www.transfermarkt.com/ben-davies/profi...
# 4  Christian Eriksen  https://www.transfermarkt.com/christian-erikse...
# Name                                                  Harry Kane
# Player Page    https://www.transfermarkt.com/harry-kane/profi...
# Name: 18, dtype: object
#                     Name                                        Player Page
# 0  Marc-André ter Stegen  https://www.transfermarkt.com/marc-andre-ter-s...
# 1        Sergio Busquets  https://www.transfermarkt.com/sergio-busquets/...
# 2          Ferran Torres  https://www.transfermarkt.com/ferran-torres/pr...
# 3             Jordi Alba  https://www.transfermarkt.com/jordi-alba/profi...
# 4        Frenkie de Jong  https://www.transfermarkt.com/frenkie-de-jong/...
# Name                                                        Gavi
# Player Page    https://www.transfermarkt.com/gavi/profil/spie...
# Name: 19, dtype: object
#              Name                                        Player Page
# 0   Franco Armani  https://www.transfermarkt.com/franco-armani/pr...
# 1           Rodri  https://www.transfermarkt.com/rodri/profil/spi...
# 2      Enzo Pérez  https://www.transfermarkt.com/enzo-perez/profi...
# 3   Manuel Akanji  https://www.transfermarkt.com/manuel-akanji/pr...
# 4  Bernardo Silva  https://www.transfermarkt.com/bernardo-silva/p...
# Name                                              Julián Alvarez
# Player Page    https://www.transfermarkt.com/julian-alvarez/p...
# Name: 20, dtype: object
#               Name                                        Player Page
# 0   Theo Hernández  https://www.transfermarkt.com/theo-hernandez/p...
# 1  Davide Calabria  https://www.transfermarkt.com/davide-calabria/...
# 2  Ismaël Bennacer  https://www.transfermarkt.com/ismael-bennacer/...
# 3     Mike Maignan  https://www.transfermarkt.com/mike-maignan/pro...
# 4    Fikayo Tomori  https://www.transfermarkt.com/fikayo-tomori/pr...
# Name                                                 Rafael Leão
# Player Page    https://www.transfermarkt.com/rafael-leao/prof...
# Name: 21, dtype: object
#              Name                                        Player Page
# 0        Dan Burn  https://www.transfermarkt.com/dan-burn/profil/...
# 1    Fabian Schär  https://www.transfermarkt.com/fabian-schar/pro...
# 2  Miguel Almirón  https://www.transfermarkt.com/miguel-almiron/p...
# 3          Santos  https://www.transfermarkt.com/santos/profil/sp...
# 4  Sean Longstaff  https://www.transfermarkt.com/sean-longstaff/p...
# Name                                             Bruno Guimarães
# Player Page    https://www.transfermarkt.com/bruno-guimaraes/...
# Name: 22, dtype: object
#                     Name                                        Player Page
# 0  Marc-André ter Stegen  https://www.transfermarkt.com/marc-andre-ter-s...
# 1        Frenkie de Jong  https://www.transfermarkt.com/frenkie-de-jong/...
# 2        Sergio Busquets  https://www.transfermarkt.com/sergio-busquets/...
# 3             Jordi Alba  https://www.transfermarkt.com/jordi-alba/profi...
# 4          Ronald Araujo  https://www.transfermarkt.com/ronald-araujo/pr...
# Name                                                       Pedri
# Player Page    https://www.transfermarkt.com/pedri/profil/spi...
# Name: 23, dtype: object
#               Name                                        Player Page
# 0     Noni Madueke  https://www.transfermarkt.com/noni-madueke/pro...
# 1   Moisés Caicedo  https://www.transfermarkt.com/moises-caicedo/p...
# 2  Conor Gallagher  https://www.transfermarkt.com/conor-gallagher/...
# 3     James McAtee  https://www.transfermarkt.com/james-mcatee/pro...
# 4  Raheem Sterling  https://www.transfermarkt.com/raheem-sterling/...
# Name                                                 Cole Palmer
# Player Page    https://www.transfermarkt.com/cole-palmer/prof...
# Name: 24, dtype: object
#                 Name                                        Player Page
# 0       Joey Veerman  https://www.transfermarkt.com/joey-veerman/pro...
# 1        Loïs Openda  https://www.transfermarkt.com/lois-openda/prof...
# 2  Benjamin Henrichs  https://www.transfermarkt.com/benjamin-henrich...
# 3         David Raum  https://www.transfermarkt.com/david-raum/profi...
# 4     Benjamin Sesko  https://www.transfermarkt.com/benjamin-sesko/p...
# Name                                                 Xavi Simons
# Player Page    https://www.transfermarkt.com/xavi-simons/prof...
# Name: 25, dtype: object
#                   Name                                        Player Page
# 0    Stanislav Lobotka  https://www.transfermarkt.com/stanislav-lobotk...
# 1  Giovanni Di Lorenzo  https://www.transfermarkt.com/giovanni-di-lore...
# 2  Zuriko Davitashvili  https://www.transfermarkt.com/zuriko-davitashv...
# 3       Frank Anguissa  https://www.transfermarkt.com/frank-anguissa/p...
# 4           Alex Meret  https://www.transfermarkt.com/alex-meret/profi...
# Name                                       Khvicha Kvaratskhelia
# Player Page    https://www.transfermarkt.com/khvicha-kvaratsk...
# Name: 26, dtype: object
#                  Name                                        Player Page
# 0   Gabriel Magalhães  https://www.transfermarkt.com/gabriel-magalhae...
# 1           Ben White  https://www.transfermarkt.com/ben-white/profil...
# 2         Bukayo Saka  https://www.transfermarkt.com/bukayo-saka/prof...
# 3  Gabriel Martinelli  https://www.transfermarkt.com/gabriel-martinel...
# 4     Martin Ødegaard  https://www.transfermarkt.com/martin-odegaard/...
# Name                                              William Saliba
# Player Page    https://www.transfermarkt.com/william-saliba/p...
# Name: 27, dtype: object
#              Name                                        Player Page
# 0  Bernardo Silva  https://www.transfermarkt.com/bernardo-silva/p...
# 1           Rodri  https://www.transfermarkt.com/rodri/profil/spi...
# 2         Ederson  https://www.transfermarkt.com/ederson/profil/s...
# 3      Phil Foden  https://www.transfermarkt.com/phil-foden/profi...
# 4           Pizzi  https://www.transfermarkt.com/pizzi/profil/spi...
# Name                                                  Rúben Dias
# Player Page    https://www.transfermarkt.com/ruben-dias/profi...
# Name: 28, dtype: object
#                  Name                                        Player Page
# 0    Lautaro Martínez  https://www.transfermarkt.com/lautaro-martinez...
# 1  Alessandro Bastoni  https://www.transfermarkt.com/alessandro-basto...
# 2      Stefan de Vrij  https://www.transfermarkt.com/stefan-de-vrij/p...
# 3    Federico Dimarco  https://www.transfermarkt.com/federico-dimarco...
# 4      Matteo Darmian  https://www.transfermarkt.com/matteo-darmian/p...
# Name                                              Nicolò Barella
# Player Page    https://www.transfermarkt.com/nicolo-barella/p...
# Name: 29, dtype: object
#                Name                                        Player Page
# 0  Pervis Estupiñán  https://www.transfermarkt.com/pervis-estupinan...
# 1   Angelo Preciado  https://www.transfermarkt.com/angelo-preciado/...
# 2    Robert Sánchez  https://www.transfermarkt.com/robert-sanchez/p...
# 3      Levi Colwill  https://www.transfermarkt.com/levi-colwill/pro...
# 4       Pascal Groß  https://www.transfermarkt.com/pascal-gross/pro...
# Name                                              Moisés Caicedo
# Player Page    https://www.transfermarkt.com/moises-caicedo/p...
# Name: 30, dtype: object
#                Name                                        Player Page
# 0    Julián Alvarez  https://www.transfermarkt.com/julian-alvarez/p...
# 1     Braian Romero  https://www.transfermarkt.com/braian-romero/pr...
# 2   Conor Gallagher  https://www.transfermarkt.com/conor-gallagher/...
# 3    David Martínez  https://www.transfermarkt.com/david-martinez/p...
# 4  Nicolás Otamendi  https://www.transfermarkt.com/nicolas-otamendi...
# Name                                              Enzo Fernández
# Player Page    https://www.transfermarkt.com/enzo-fernandez/p...
# Name: 31, dtype: object
#                 Name                                        Player Page
# 0         Lewis Dunk  https://www.transfermarkt.com/lewis-dunk/profi...
# 1        Pascal Groß  https://www.transfermarkt.com/pascal-gross/pro...
# 2       Joël Veltman  https://www.transfermarkt.com/joel-veltman/pro...
# 3  Jonathan Sandoval  https://www.transfermarkt.com/jonathan-sandova...
# 4     Robert Sánchez  https://www.transfermarkt.com/robert-sanchez/p...
# Name                                         Alexis Mac Allister
# Player Page    https://www.transfermarkt.com/alexis-mac-allis...
# Name: 32, dtype: object
#               Name                                        Player Page
# 0     Mateus Uribe  https://www.transfermarkt.com/mateus-uribe/pro...
# 1           Otávio  https://www.transfermarkt.com/otavio/profil/sp...
# 2   Chancel Mbemba  https://www.transfermarkt.com/chancel-mbemba/p...
# 3  Virgil van Dijk  https://www.transfermarkt.com/virgil-van-dijk/...
# 4  Sebastián Viera  https://www.transfermarkt.com/sebastian-viera/...
# Name                                                   Luis Díaz
# Player Page    https://www.transfermarkt.com/luis-diaz/profil...
# Name: 33, dtype: object
#                  Name                                        Player Page
# 0         André Silva  https://www.transfermarkt.com/andre-silva/prof...
# 1         Willi Orbán  https://www.transfermarkt.com/willi-orban/prof...
# 2   Dominik Livakovic  https://www.transfermarkt.com/dominik-livakovi...
# 3  Dominik Szoboszlai  https://www.transfermarkt.com/dominik-szoboszl...
# 4  Christopher Nkunku  https://www.transfermarkt.com/christopher-nkun...
# Name                                              Josko Gvardiol
# Player Page    https://www.transfermarkt.com/josko-gvardiol/p...
# Name: 34, dtype: object
#              Name                                        Player Page
# 0     Willi Orbán  https://www.transfermarkt.com/willi-orban/prof...
# 1   Péter Gulácsi  https://www.transfermarkt.com/peter-gulacsi/pr...
# 2     Enock Mwepu  https://www.transfermarkt.com/enock-mwepu/prof...
# 3   Andreas Ulmer  https://www.transfermarkt.com/andreas-ulmer/pr...
# 4  Josko Gvardiol  https://www.transfermarkt.com/josko-gvardiol/p...
# Name                                          Dominik Szoboszlai
# Player Page    https://www.transfermarkt.com/dominik-szoboszl...
# Name: 35, dtype: object
#                Name                                        Player Page
# 0  Robin Le Normand  https://www.transfermarkt.com/robin-le-normand...
# 1       Álex Remiro  https://www.transfermarkt.com/alex-remiro/prof...
# 2      Mikel Merino  https://www.transfermarkt.com/mikel-merino/pro...
# 3   Mikel Oyarzabal  https://www.transfermarkt.com/mikel-oyarzabal/...
# 4             Portu  https://www.transfermarkt.com/portu/profil/spi...
# Name                                              Alexander Isak
# Player Page    https://www.transfermarkt.com/alexander-isak/p...
# Name: 36, dtype: object
#              Name                                        Player Page
# 0  Iñaki Williams  https://www.transfermarkt.com/inaki-williams/p...
# 1      Unai Simón  https://www.transfermarkt.com/unai-simon/profi...
# 2    Oihan Sancet  https://www.transfermarkt.com/oihan-sancet/pro...
# 3     Dani Vivian  https://www.transfermarkt.com/dani-vivian/prof...
# 4     Mikel Vesga  https://www.transfermarkt.com/mikel-vesga/prof...
# Name                                               Nico Williams
# Player Page    https://www.transfermarkt.com/nico-williams/pr...
# Name: 37, dtype: object
#                 Name                                        Player Page
# 0        Bukayo Saka  https://www.transfermarkt.com/bukayo-saka/prof...
# 1  Gabriel Magalhães  https://www.transfermarkt.com/gabriel-magalhae...
# 2    Martin Ødegaard  https://www.transfermarkt.com/martin-odegaard/...
# 3          Ben White  https://www.transfermarkt.com/ben-white/profil...
# 4       Granit Xhaka  https://www.transfermarkt.com/granit-xhaka/pro...
# Name                                          Gabriel Martinelli
# Player Page    https://www.transfermarkt.com/gabriel-martinel...
# Name: 38, dtype: object
#                      Name                                        Player Page
# 0           Mohamed Salah  https://www.transfermarkt.com/mohamed-salah/pr...
# 1         Virgil van Dijk  https://www.transfermarkt.com/virgil-van-dijk/...
# 2  Trent Alexander-Arnold  https://www.transfermarkt.com/trent-alexander-...
# 3          Jan Vertonghen  https://www.transfermarkt.com/jan-vertonghen/p...
# 4                 Alisson  https://www.transfermarkt.com/alisson/profil/s...
# Name                                                Darwin Núñez
# Player Page    https://www.transfermarkt.com/darwin-nunez/pro...
# Name: 39, dtype: object
#                     Name                                        Player Page
# 0  Marc-André ter Stegen  https://www.transfermarkt.com/marc-andre-ter-s...
# 1        Frenkie de Jong  https://www.transfermarkt.com/frenkie-de-jong/...
# 2        Sergio Busquets  https://www.transfermarkt.com/sergio-busquets/...
# 3                  Pedri  https://www.transfermarkt.com/pedri/profil/spi...
# 4             Jordi Alba  https://www.transfermarkt.com/jordi-alba/profi...
# Name                                               Ronald Araujo
# Player Page    https://www.transfermarkt.com/ronald-araujo/pr...
# Name: 40, dtype: object
#                 Name                                        Player Page
# 0        John McGinn  https://www.transfermarkt.com/john-mcginn/prof...
# 1         Ezri Konsa  https://www.transfermarkt.com/ezri-konsa/profi...
# 2      Ollie Watkins  https://www.transfermarkt.com/ollie-watkins/pr...
# 3  Emiliano Martínez  https://www.transfermarkt.com/emiliano-martine...
# 4       Tyrone Mings  https://www.transfermarkt.com/tyrone-mings/pro...
# Name                                                Douglas Luiz
# Player Page    https://www.transfermarkt.com/douglas-luiz/pro...
# Name: 41, dtype: object
#                  Name                                        Player Page
# 0         Bukayo Saka  https://www.transfermarkt.com/bukayo-saka/prof...
# 1     Martin Ødegaard  https://www.transfermarkt.com/martin-odegaard/...
# 2  Gabriel Martinelli  https://www.transfermarkt.com/gabriel-martinel...
# 3           Ben White  https://www.transfermarkt.com/ben-white/profil...
# 4       Eddie Nketiah  https://www.transfermarkt.com/eddie-nketiah/pr...
# Name                                           Gabriel Magalhães
# Player Page    https://www.transfermarkt.com/gabriel-magalhae...
# Name: 42, dtype: object
#                     Name                                        Player Page
# 0  Marc-André ter Stegen  https://www.transfermarkt.com/marc-andre-ter-s...
# 1        Sergio Busquets  https://www.transfermarkt.com/sergio-busquets/...
# 2             Jordi Alba  https://www.transfermarkt.com/jordi-alba/profi...
# 3       Matthijs de Ligt  https://www.transfermarkt.com/matthijs-de-ligt...
# 4          Ronald Araujo  https://www.transfermarkt.com/ronald-araujo/pr...
# Name                                             Frenkie de Jong
# Player Page    https://www.transfermarkt.com/frenkie-de-jong/...
# Name: 43, dtype: object
#                Name                                        Player Page
# 0    Nicolò Barella  https://www.transfermarkt.com/nicolo-barella/p...
# 1  Lautaro Martínez  https://www.transfermarkt.com/lautaro-martinez...
# 2    Matteo Darmian  https://www.transfermarkt.com/matteo-darmian/p...
# 3  Marcelo Brozovic  https://www.transfermarkt.com/marcelo-brozovic...
# 4    Stefan de Vrij  https://www.transfermarkt.com/stefan-de-vrij/p...
# Name                                          Alessandro Bastoni
# Player Page    https://www.transfermarkt.com/alessandro-basto...
# Name: 44, dtype: object
#                Name                                        Player Page
# 0     Mohamed Salah  https://www.transfermarkt.com/mohamed-salah/pr...
# 1  Andrew Robertson  https://www.transfermarkt.com/andrew-robertson...
# 2           Alisson  https://www.transfermarkt.com/alisson/profil/s...
# 3   Virgil van Dijk  https://www.transfermarkt.com/virgil-van-dijk/...
# 4   Roberto Firmino  https://www.transfermarkt.com/roberto-firmino/...
# Name                                      Trent Alexander-Arnold
# Player Page    https://www.transfermarkt.com/trent-alexander-...
# Name: 45, dtype: object
#             Name                                        Player Page
# 0   Jonathan Tah  https://www.transfermarkt.com/jonathan-tah/pro...
# 1  Kevin Volland  https://www.transfermarkt.com/kevin-volland/pr...
# 2       Jorginho  https://www.transfermarkt.com/jorginho/profil/...
# 3        Wendell  https://www.transfermarkt.com/wendell/profil/s...
# 4  Julian Brandt  https://www.transfermarkt.com/julian-brandt/pr...
# Name                                                 Kai Havertz
# Player Page    https://www.transfermarkt.com/kai-havertz/prof...
# Name: 46, dtype: object
#                 Name                                        Player Page
# 0  Kasper Schmeichel  https://www.transfermarkt.com/kasper-schmeiche...
# 1    Youri Tielemans  https://www.transfermarkt.com/youri-tielemans/...
# 2        Jamie Vardy  https://www.transfermarkt.com/jamie-vardy/prof...
# 3      Harvey Barnes  https://www.transfermarkt.com/harvey-barnes/pr...
# 4      Wilfred Ndidi  https://www.transfermarkt.com/wilfred-ndidi/pr...
# Name                                              James Maddison
# Player Page    https://www.transfermarkt.com/james-maddison/p...
# Name: 47, dtype: object
#               Name                                        Player Page
# 0          Ederson  https://www.transfermarkt.com/ederson/profil/s...
# 1      Kyle Walker  https://www.transfermarkt.com/kyle-walker/prof...
# 2   İlkay Gündoğan  https://www.transfermarkt.com/ilkay-gundogan/p...
# 3  Kevin De Bruyne  https://www.transfermarkt.com/kevin-de-bruyne/...
# 4     João Cancelo  https://www.transfermarkt.com/joao-cancelo/pro...
# Name                                              Bernardo Silva
# Player Page    https://www.transfermarkt.com/bernardo-silva/p...
# Name: 48, dtype: object
#                 Name                                        Player Page
# 0    Marcus Rashford  https://www.transfermarkt.com/marcus-rashford/...
# 1      Harry Maguire  https://www.transfermarkt.com/harry-maguire/pr...
# 2    Scott McTominay  https://www.transfermarkt.com/scott-mctominay/...
# 3  Aaron Wan-Bissaka  https://www.transfermarkt.com/aaron-wan-bissak...
# 4    Victor Lindelöf  https://www.transfermarkt.com/victor-lindelof/...
# Name                                             Bruno Fernandes
# Player Page    https://www.transfermarkt.com/bruno-fernandes/...
# Name: 49, dtype: object
#              Name                                        Player Page
# 0  Joshua Kimmich  https://www.transfermarkt.com/joshua-kimmich/p...
# 1   Leon Goretzka  https://www.transfermarkt.com/leon-goretzka/pr...
# 2   Thomas Müller  https://www.transfermarkt.com/thomas-muller/pr...
# 3    Manuel Neuer  https://www.transfermarkt.com/manuel-neuer/pro...
# 4   Jamal Musiala  https://www.transfermarkt.com/jamal-musiala/pr...
# Name                                                  Leroy Sané
# Player Page    https://www.transfermarkt.com/leroy-sane/profi...
# Name: 50, dtype: object
#                  Name                                        Player Page
# 0       Joakim Maehle  https://www.transfermarkt.com/joakim-maehle/pr...
# 1      William Bøving  https://www.transfermarkt.com/william-boving/p...
# 2         André Onana  https://www.transfermarkt.com/andre-onana/prof...
# 3  Victor Kristiansen  https://www.transfermarkt.com/victor-kristians...
# 4         Diogo Dalot  https://www.transfermarkt.com/diogo-dalot/prof...
# Name                                              Rasmus Højlund
# Player Page    https://www.transfermarkt.com/rasmus-hojlund/p...
# Name: 51, dtype: object
#                   Name                                        Player Page
# 0  Benjamin Bourigeaud  https://www.transfermarkt.com/benjamin-bourige...
# 1        Hamari Traoré  https://www.transfermarkt.com/hamari-traore/pr...
# 2      Adrien Truffert  https://www.transfermarkt.com/adrien-truffert/...
# 3         Flavien Tait  https://www.transfermarkt.com/flavien-tait/pro...
# 4       Martin Terrier  https://www.transfermarkt.com/martin-terrier/p...
# Name                                                 Jérémy Doku
# Player Page    https://www.transfermarkt.com/jeremy-doku/prof...
# Name: 52, dtype: object
#               Name                                        Player Page
# 0          Emerson  https://www.transfermarkt.com/emerson/profil/s...
# 1     Jarrod Bowen  https://www.transfermarkt.com/jarrod-bowen/pro...
# 2  Everton Ribeiro  https://www.transfermarkt.com/everton-ribeiro/...
# 3     Tomas Soucek  https://www.transfermarkt.com/tomas-soucek/pro...
# 4  Vladimír Coufal  https://www.transfermarkt.com/vladimir-coufal/...
# Name                                               Lucas Paquetá
# Player Page    https://www.transfermarkt.com/lucas-paqueta/pr...
# Name: 53, dtype: object
#               Name                                        Player Page
# 0          Ederson  https://www.transfermarkt.com/ederson/profil/s...
# 1  Raheem Sterling  https://www.transfermarkt.com/raheem-sterling/...
# 2      Fernandinho  https://www.transfermarkt.com/fernandinho/prof...
# 3   Bernardo Silva  https://www.transfermarkt.com/bernardo-silva/p...
# 4   İlkay Gündoğan  https://www.transfermarkt.com/ilkay-gundogan/p...
# Name                                               Gabriel Jesus
# Player Page    https://www.transfermarkt.com/gabriel-jesus/pr...
# Name: 54, dtype: object
#                 Name                                        Player Page
# 0  Nikola Milenković  https://www.transfermarkt.com/nikola-milenkovi...
# 1             Danilo  https://www.transfermarkt.com/danilo/profil/sp...
# 2   Manuel Locatelli  https://www.transfermarkt.com/manuel-locatelli...
# 3      Adrien Rabiot  https://www.transfermarkt.com/adrien-rabiot/pr...
# 4    Federico Chiesa  https://www.transfermarkt.com/federico-chiesa/...
# Name                                              Dušan Vlahović
# Player Page    https://www.transfermarkt.com/dusan-vlahovic/p...
# Name: 55, dtype: object
#                     Name                                        Player Page
# 0          Heung-min Son  https://www.transfermarkt.com/heung-min-son/pr...
# 1  Pierre-Emile Højbjerg  https://www.transfermarkt.com/pierre-emile-hoj...
# 2       Dejan Kulusevski  https://www.transfermarkt.com/dejan-kulusevski...
# 3          Emerson Royal  https://www.transfermarkt.com/emerson-royal/pr...
# 4             Harry Kane  https://www.transfermarkt.com/harry-kane/profi...
# Name                                             Cristian Romero
# Player Page    https://www.transfermarkt.com/cristian-romero/...
# Name: 56, dtype: object
#                 Name                                        Player Page
# 0      Péter Gulácsi  https://www.transfermarkt.com/peter-gulacsi/pr...
# 1        Willi Orbán  https://www.transfermarkt.com/willi-orban/prof...
# 2      Emil Forsberg  https://www.transfermarkt.com/emil-forsberg/pr...
# 3  Lukas Klostermann  https://www.transfermarkt.com/lukas-klosterman...
# 4        Kevin Kampl  https://www.transfermarkt.com/kevin-kampl/prof...
# Name                                          Christopher Nkunku
# Player Page    https://www.transfermarkt.com/christopher-nkun...
# Name: 57, dtype: object
#                 Name                                        Player Page
# 0  Donny van de Beek  https://www.transfermarkt.com/donny-van-de-bee...
# 1    Frenkie de Jong  https://www.transfermarkt.com/frenkie-de-jong/...
# 2  Noussair Mazraoui  https://www.transfermarkt.com/noussair-mazraou...
# 3        André Onana  https://www.transfermarkt.com/andre-onana/prof...
# 4       Hakim Ziyech  https://www.transfermarkt.com/hakim-ziyech/pro...
# Name                                            Matthijs de Ligt
# Player Page    https://www.transfermarkt.com/matthijs-de-ligt...
# Name: 58, dtype: object
#              Name                                        Player Page
# 0   Gustavo Hamer  https://www.transfermarkt.com/gustavo-hamer/pr...
# 1  Kyle McFadzean  https://www.transfermarkt.com/kyle-mcfadzean/p...
# 2     Jamie Allen  https://www.transfermarkt.com/jamie-allen/prof...
# 3       Ben Sheaf  https://www.transfermarkt.com/ben-sheaf/profil...
# 4    Jake Bidwell  https://www.transfermarkt.com/jake-bidwell/pro...
# Name                                             Viktor Gyökeres
# Player Page    https://www.transfermarkt.com/viktor-gyokeres/...
# Name: 59, dtype: object
#                 Name                                        Player Page
# 0         Ezri Konsa  https://www.transfermarkt.com/ezri-konsa/profi...
# 1        John McGinn  https://www.transfermarkt.com/john-mcginn/prof...
# 2  Emiliano Martínez  https://www.transfermarkt.com/emiliano-martine...
# 3       Douglas Luiz  https://www.transfermarkt.com/douglas-luiz/pro...
# 4         Matty Cash  https://www.transfermarkt.com/matty-cash/profi...
# Name                                               Ollie Watkins
# Player Page    https://www.transfermarkt.com/ollie-watkins/pr...
# Name: 60, dtype: object
#               Name                                        Player Page
# 0      Yann Sommer  https://www.transfermarkt.com/yann-sommer/prof...
# 1      Nico Elvedi  https://www.transfermarkt.com/nico-elvedi/prof...
# 2  Florian Neuhaus  https://www.transfermarkt.com/florian-neuhaus/...
# 3    Alassane Plea  https://www.transfermarkt.com/alassane-plea/pr...
# 4    Stefan Lainer  https://www.transfermarkt.com/stefan-lainer/pr...
# Name                                               Marcus Thuram
# Player Page    https://www.transfermarkt.com/marcus-thuram/pr...
# Name: 61, dtype: object
#                Name                                        Player Page
# 0          Weverton  https://www.transfermarkt.com/weverton/profil/...
# 1     Gustavo Gómez  https://www.transfermarkt.com/gustavo-gomez/pr...
# 2  Joaquín Piquerez  https://www.transfermarkt.com/joaquin-piquerez...
# 3            Murilo  https://www.transfermarkt.com/murilo/profil/sp...
# 4     Raphael Veiga  https://www.transfermarkt.com/raphael-veiga/pr...
# Name                                                     Endrick
# Player Page    https://www.transfermarkt.com/endrick/profil/s...
# Name: 62, dtype: object
#                    Name                                        Player Page
# 0  Gianluigi Donnarumma  https://www.transfermarkt.com/gianluigi-donnar...
# 1         Kylian Mbappé  https://www.transfermarkt.com/kylian-mbappe/pr...
# 2               Vitinha  https://www.transfermarkt.com/vitinha/profil/s...
# 3            Marquinhos  https://www.transfermarkt.com/marquinhos/profi...
# 4         Achraf Hakimi  https://www.transfermarkt.com/achraf-hakimi/pr...
# Name                                          Warren Zaïre-Emery
# Player Page    https://www.transfermarkt.com/warren-zaire-eme...
# Name: 63, dtype: object
#                Name                                        Player Page
# 0        Saša Lukić  https://www.transfermarkt.com/sasa-lukic/profi...
# 1    Andrea Belotti  https://www.transfermarkt.com/andrea-belotti/p...
# 2  Manuel Locatelli  https://www.transfermarkt.com/manuel-locatelli...
# 3            Danilo  https://www.transfermarkt.com/danilo/profil/sp...
# 4    Dušan Vlahović  https://www.transfermarkt.com/dusan-vlahovic/p...
# Name                                                      Bremer
# Player Page    https://www.transfermarkt.com/bremer/profil/sp...
# Name: 64, dtype: object
#               Name                                        Player Page
# 0  Jordan Pickford  https://www.transfermarkt.com/jordan-pickford/...
# 1  Bruno Guimarães  https://www.transfermarkt.com/bruno-guimaraes/...
# 2     Fabian Schär  https://www.transfermarkt.com/fabian-schar/pro...
# 3         Dan Burn  https://www.transfermarkt.com/dan-burn/profil/...
# 4  Kieran Trippier  https://www.transfermarkt.com/kieran-trippier/...
# Name                                              Anthony Gordon
# Player Page    https://www.transfermarkt.com/anthony-gordon/p...
# Name: 65, dtype: object
#                 Name                                        Player Page
# 0    Vinicius Junior  https://www.transfermarkt.com/vinicius-junior/...
# 1            Rodrygo  https://www.transfermarkt.com/rodrygo/profil/s...
# 2   Thibaut Courtois  https://www.transfermarkt.com/thibaut-courtois...
# 3  Federico Valverde  https://www.transfermarkt.com/federico-valverd...
# 4        Luka Modric  https://www.transfermarkt.com/luka-modric/prof...
# Name                                                Éder Militão
# Player Page    https://www.transfermarkt.com/eder-militao/pro...
# Name: 66, dtype: object
#                    Name                                        Player Page
# 0         Kylian Mbappé  https://www.transfermarkt.com/kylian-mbappe/pr...
# 1            Marquinhos  https://www.transfermarkt.com/marquinhos/profi...
# 2  Gianluigi Donnarumma  https://www.transfermarkt.com/gianluigi-donnar...
# 3        Danilo Pereira  https://www.transfermarkt.com/danilo-pereira/p...
# 4               Vitinha  https://www.transfermarkt.com/vitinha/profil/s...
# Name                                               Achraf Hakimi
# Player Page    https://www.transfermarkt.com/achraf-hakimi/pr...
# Name: 67, dtype: object
#                 Name                                        Player Page
# 0     Danilho Doekhi  https://www.transfermarkt.com/danilho-doekhi/p...
# 1           Eli Dasa  https://www.transfermarkt.com/eli-dasa/profil/...
# 2   Riechedly Bazoer  https://www.transfermarkt.com/riechedly-bazoer...
# 3    Sondre Tronstad  https://www.transfermarkt.com/sondre-tronstad/...
# 4  Maximilian Wittek  https://www.transfermarkt.com/maximilian-witte...
# Name                                                 Loïs Openda
# Player Page    https://www.transfermarkt.com/lois-openda/prof...
# Name: 68, dtype: object
#               Name                                        Player Page
# 0      Rafael Leão  https://www.transfermarkt.com/rafael-leao/prof...
# 1  Ismaël Bennacer  https://www.transfermarkt.com/ismael-bennacer/...
# 2  Davide Calabria  https://www.transfermarkt.com/davide-calabria/...
# 3   Olivier Giroud  https://www.transfermarkt.com/olivier-giroud/p...
# 4    Fikayo Tomori  https://www.transfermarkt.com/fikayo-tomori/pr...
# Name                                              Theo Hernández
# Player Page    https://www.transfermarkt.com/theo-hernandez/p...
# Name: 69, dtype: object
#                  Name                                        Player Page
# 0         Willi Orbán  https://www.transfermarkt.com/willi-orban/prof...
# 1       Péter Gulácsi  https://www.transfermarkt.com/peter-gulacsi/pr...
# 2         Kevin Kampl  https://www.transfermarkt.com/kevin-kampl/prof...
# 3          Amer Gojak  https://www.transfermarkt.com/amer-gojak/profi...
# 4  Christopher Nkunku  https://www.transfermarkt.com/christopher-nkun...
# Name                                                   Dani Olmo
# Player Page    https://www.transfermarkt.com/dani-olmo/profil...
# Name: 70, dtype: object
#                     Name                                        Player Page
# 0  Marc-André ter Stegen  https://www.transfermarkt.com/marc-andre-ter-s...
# 1        Sergio Busquets  https://www.transfermarkt.com/sergio-busquets/...
# 2             Jordi Alba  https://www.transfermarkt.com/jordi-alba/profi...
# 3           Gerard Piqué  https://www.transfermarkt.com/gerard-pique/pro...
# 4        Frenkie de Jong  https://www.transfermarkt.com/frenkie-de-jong/...
# Name                                             Ousmane Dembélé
# Player Page    https://www.transfermarkt.com/ousmane-dembele/...
# Name: 71, dtype: object
#               Name                                        Player Page
# 0     David de Gea  https://www.transfermarkt.com/david-de-gea/pro...
# 1  Victor Lindelöf  https://www.transfermarkt.com/victor-lindelof/...
# 2        Luke Shaw  https://www.transfermarkt.com/luke-shaw/profil...
# 3    Harry Maguire  https://www.transfermarkt.com/harry-maguire/pr...
# 4  Bruno Fernandes  https://www.transfermarkt.com/bruno-fernandes/...
# Name                                             Marcus Rashford
# Player Page    https://www.transfermarkt.com/marcus-rashford/...
# Name: 72, dtype: object
#               Name                                        Player Page
# 0   Bernardo Silva  https://www.transfermarkt.com/bernardo-silva/p...
# 1            Rodri  https://www.transfermarkt.com/rodri/profil/spi...
# 2          Ederson  https://www.transfermarkt.com/ederson/profil/s...
# 3  Conor Hourihane  https://www.transfermarkt.com/conor-hourihane/...
# 4      Kyle Walker  https://www.transfermarkt.com/kyle-walker/prof...
# Name                                               Jack Grealish
# Player Page    https://www.transfermarkt.com/jack-grealish/pr...
# Name: 73, dtype: object
#                  Name                                        Player Page
# 0  Alejandro Garnacho  https://www.transfermarkt.com/alejandro-garnac...
# 1         Marc Jurado  https://www.transfermarkt.com/marc-jurado/prof...
# 2         Diogo Dalot  https://www.transfermarkt.com/diogo-dalot/prof...
# 3         André Onana  https://www.transfermarkt.com/andre-onana/prof...
# 4     Bruno Fernandes  https://www.transfermarkt.com/bruno-fernandes/...
# Name                                               Kobbie Mainoo
# Player Page    https://www.transfermarkt.com/kobbie-mainoo/pr...
# Name: 74, dtype: object

# %%
# Remove duplicates from the players data
df_players = pd.DataFrame.from_dict(players_data)
df_players = df_players.drop_duplicates()

# Regenerate the teammates page column after adding teammates
df_players['Teammates Page'] = df_players.apply(teamates_page, axis=1)

# Save the updated player data with teammates pages to a CSV file
df_players.to_csv('out.csv', index=False)

# %% [markdown]
# ## 6. Plotting the Graph Built
# In this section, we visualize the graph created in the previous step. The graph displays players as nodes and their connections (teammates) as edges. The size and color of the nodes represent the number of connections (teammates) a player has, giving insight into which players are central to the network.
#
# We use the NetworkX `spring_layout()` to position the nodes and Plotly to create an interactive plot where users can hover over nodes to see player names and their connection count.

# %%
# Position nodes in the graph using a spring layout
pos = nx.spring_layout(G)

# Extract edge positions
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)  # For separating edges in the plot
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

# Create the edge trace (lines)
edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=1, color='black'),
    hoverinfo='none',
    mode='lines'
)

# Extract node positions
node_x = []
node_y = []
for node in G.nodes():
    x, y = pos[node]
    node_x.append(x)
    node_y.append(y)

# Node adjacency and hover text
node_adjacencies = []
node_text = []
for node, adjacencies in G.adjacency():
    num_connections = len(adjacencies)  # Number of connections for the node
    node_adjacencies.append(num_connections)
    node_text.append(f"Node {extract_player_name(node)} has {num_connections} connections")

# Create the node trace (points)
node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        colorscale='viridis',
        size=10,
        color=node_adjacencies,
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
    )
)

# Assign node hover text
node_trace.text = node_text

# Create the plot
fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                    title='Interactive Network Graph',
                    titlefont_size=16,
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=0, l=0, r=0, t=40),
                    annotations=[dict(
                        text="Network visualization using NetworkX and Plotly",
                        showarrow=False,
                        xref="paper", yref="paper",
                        x=0.005, y=-0.002
                    )],
                    xaxis=dict(showgrid=False, zeroline=False),
                    yaxis=dict(showgrid=False, zeroline=False)
                )
)

# Display the graph
fig.show()

# %% [markdown]
# ## 7. Interactive Section to Check for Shortest Path Between Players
# In this section, we allow the user to interactively check for the shortest path between two players in the network. The user inputs the names of the two players, and the notebook calculates and displays the shortest path, if one exists, between them in the graph. The path is represented as a sequence of player names, showing how the two players are connected through the network.

# %%
# Interactive input to find the shortest path between two players
player1 = input("Enter the first player's name: ")
player2 = input("Enter the second player's name: ")

# Check if both players are in the graph
if check_players_in_graph(G, player1, player2):
    try:
        # Find the shortest path between the two players
        path = nx.shortest_path(G, 
                                source=[node for node in G.nodes if name_to_url(player1) in node][0], 
                                target=[node for node in G.nodes if name_to_url(player2) in node][0])
        
        # Print the path and its length
        print(f"The path has a {len(path)} length and it is formed by the following players:")
        for node in path:
            print(extract_player_name(node), end=" - ")
    except nx.NetworkXNoPath:
        print(f'There is no known path between {player1} and {player2}')
# Out:
# There is no known path between Bernardo Silva and Marco Reus

# %% [markdown]
# # 8. Ending the Selenium Process

# %%
# Close the browser
wd.quit()
